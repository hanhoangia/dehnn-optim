# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Importing the dataset
losses = pd.read_csv('2025-02-20_01-50-36/losses.csv')
# make epoch the index
losses = losses.set_index('epoch')
losses
# Out:
#        train_node_loss  train_net_loss  val_node_loss  val_net_loss
# epoch
# 0             1.024171        1.002754       1.010383      1.004706
# 1             1.011227        0.999725       1.004446      1.000970
# 2             1.004044        0.997740       1.002074      0.998864
# 3             1.000808        0.996037       1.001885      0.997146
# 4             0.999894        0.994759       1.002266      0.995722
# ...                ...             ...            ...           ...
# 84            0.963479        0.858122       1.022756      0.908501
# 85            0.963192        0.856999       1.021456      0.912053
# 86            0.962681        0.856423       1.022441      0.912673
# 87            0.962084        0.855404       1.022840      0.906435
# 88            0.961843        0.854722       1.024030      0.914158
#
# [89 rows x 4 columns]

# %%
# plot train_node_loss and val_node_loss on the same graph using line plot
losses[['train_node_loss', 'val_node_loss']].plot()
plt.title('Train and Validation Node Loss for Configuration 2')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.savefig('loss_curve_2.png')
plt.show()

# %%
losses_2 = pd.read_csv('2025-02-20_02-19-26/losses.csv')
# make epoch the index
losses_2 = losses_2.set_index('epoch')

# %%
# plot train_node_loss and val_node_loss on the same graph using line plot
losses_2[['train_node_loss', 'val_node_loss']].plot()
plt.title('Train and Validation Node Loss for Configuration 1')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.savefig('loss_curve_1.png')
plt.show()

# %%
losses_3 = pd.read_csv('losses.csv')
# make epoch the index
losses_3 = losses_3.set_index('epoch')

# %%
# plot train_node_loss and val_node_loss on the same graph using line plot
losses_3[['train_node_loss', 'val_node_loss']].plot()
plt.title('Train and Validation Node Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
losses_rebench = pd.read_csv('losses_rebenchmark.csv')
# make epoch the index
losses_rebench = losses_rebench.set_index('epoch')

# plot train_node_loss and val_node_loss on the same graph using line plot
# plot train_net_loss and val_net_loss on the same graph using line plot
# using subplots
fig, axs = plt.subplots(2, 1, figsize=(10, 10))
losses_rebench[['train_node_loss', 'val_node_loss']].plot(ax=axs[0])
axs[0].set_title('Train and Validation Node Loss')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Loss')
losses_rebench[['train_net_loss', 'val_net_loss']].plot(ax=axs[1])
axs[1].set_title('Train and Validation Net Loss')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Loss')
plt.tight_layout()
plt.savefig('loss_curve_rebench.png')
plt.show()

# %%
losses_earlystop = pd.read_csv('losses_earlystop.csv')
# make epoch the index
losses_earlystop = losses_earlystop.set_index('epoch')

# plot train_node_loss and val_node_loss on the same graph using line plot
# plot train_net_loss and val_net_loss on the same graph using line plot
# using subplots
fig, axs = plt.subplots(2, 1, figsize=(10, 10))
losses_earlystop[['train_node_loss', 'val_node_loss']].plot(ax=axs[0])
axs[0].set_title('Train and Validation Node Loss')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Loss')
losses_earlystop[['train_net_loss', 'val_net_loss']].plot(ax=axs[1])
axs[1].set_title('Train and Validation Net Loss')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Loss')
plt.tight_layout()
plt.savefig('loss_curve_earlystop.png')
plt.show()
