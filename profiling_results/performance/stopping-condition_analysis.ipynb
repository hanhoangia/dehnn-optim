# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Importing the dataset
losses = pd.read_csv('losses.csv')
# make epoch the index
losses = losses.set_index('epoch')
losses
# Out:
#        train_node_loss  train_net_loss  val_node_loss  val_net_loss
# epoch
# 0             1.127577        1.443737       1.019235      1.010613
# 1             1.014037        1.014093       1.022050      1.017739
# 2             1.007247        1.006346       1.003927      1.005663
# 3             1.002105        1.001565       1.005445      1.002383
# 4             1.000487        0.999570       1.007496      0.997597
# ...                ...             ...            ...           ...
# 88            0.973208        0.950374       1.062628      1.108325
# 89            0.980441        0.947544       1.007395      1.086970
# 90            0.975189        0.947965       0.987758      1.104577
# 91            0.971285        0.949048       0.999469      1.061804
# 92            0.969263        0.947583       1.038761      1.082977
#
# [93 rows x 4 columns]

# %%
# plot train_node_loss and val_node_loss on the same graph using line plot
losses[['train_node_loss', 'val_node_loss']].plot()
plt.title('Train and Validation Node Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
losses_2 = pd.read_csv('losses_2.csv')
# make epoch the index
losses_2 = losses_2.set_index('epoch')

# %%
# plot train_node_loss and val_node_loss on the same graph using line plot
losses_2[['train_node_loss', 'val_node_loss']].plot()
plt.title('Train and Validation Node Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
losses_3 = pd.read_csv('losses_3.csv')
# make epoch the index
losses_3 = losses_3.set_index('epoch')

# %%
# plot train_node_loss and val_node_loss on the same graph using line plot
losses_3[['train_node_loss', 'val_node_loss']].plot()
plt.title('Train and Validation Node Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')
